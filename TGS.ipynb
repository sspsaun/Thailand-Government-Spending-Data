# %% [markdown]
# <a href="https://colab.research.google.com/github/sspsaun/Thailand-Government-Spending-Data/blob/main/TGS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Collection & Preparation, Exploratory Data Analysis (EDA) and Data Visualization**

# %% [markdown]
# ## **Import Libraries**

# %%
from requests import request
import bs4
from pprint import pprint
import urllib
import urllib.request
import requests
import pandas as pd
import json
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import plotly.express as px
# %matplotlib inline

# %%
import sys
sys.version
# Out:
# '3.8.16 (default, Dec  7 2022, 01:12:13) \n[GCC 7.5.0]'

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
matplotlib.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')

# %%
plt.rc('font', family='TH Sarabun New', size=20)

# %%
pd.set_option('float_format', '{:f}'.format)

# %% [markdown]
# ## Task 1: Identify one or more suitable web API(s)

# %% [markdown]
# **API :** เลือกใช้ api จากเว็บไซต์ https://govspending.data.go.th/ ซึ่งเป็นเว็บไซต์ที่รวบรวมข้อมูลเกี่ยวกับการใช้จ่ายของภาครัฐ เช่น ข้อมูลโครงการจัดซื้อจัดจ้าง ข้อมูลงบประมาณและการเบิกจ่าย เป็นต้น
#
# **ขอบเขต :** วิเคราะห์ข้อมูลงบประมาณภาครัฐตั้งแต่ปี 2560-2564

# %% [markdown]
# ## Task 2: Collect data your chosen API(s)

# %%
#ดึงข้อมูลโครงการจัดซื้อจัดจ้างของปี 2560
params = {"api-key": "tLBAbdSekSd16oBfoeFnosXS28xtWomG","year":"2560","limit":"2000"}
response = requests.get("https://opend.data.go.th/govspending/cgdcontract?", params)
data60 = response.json()["result"]

# %%
#ดึงข้อมูลโครงการจัดซื้อจัดจ้างของปี 2561
params = {"api-key": "tLBAbdSekSd16oBfoeFnosXS28xtWomG","year":"2561","limit":"2000"}
response = requests.get("https://opend.data.go.th/govspending/cgdcontract?", params)
data61 = response.json()["result"]

# %%
#ดึงข้อมูลโครงการจัดซื้อจัดจ้างของปี 2562
params = {"api-key": "tLBAbdSekSd16oBfoeFnosXS28xtWomG","year":"2562","limit":"2000"}
response = requests.get("https://opend.data.go.th/govspending/cgdcontract?", params)
data62 = response.json()["result"]

# %%
#ดึงข้อมูลโครงการจัดซื้อจัดจ้างของปี 2563
params = {"api-key": "tLBAbdSekSd16oBfoeFnosXS28xtWomG","year":"2563","limit":"2000"}
response = requests.get("https://opend.data.go.th/govspending/cgdcontract?", params)
data63 = response.json()["result"]

# %%
#ดึงข้อมูลโครงการจัดซื้อจัดจ้างของปี 2564
params = {"api-key": "tLBAbdSekSd16oBfoeFnosXS28xtWomG","year":"2564","limit":"2000"}
response = requests.get("https://opend.data.go.th/govspending/cgdcontract?", params)
data64 = response.json()["result"]

# %% [markdown]
# ## Task 3: Parse the collected data, and store it in an appropriate file format

# %%
#สร้างฟังก์ชันเพื่อเก็บข้อมูลที่จะใช้ และสร้างเป็น dataframe
def create_df(data):
  project_id, project_name, project_type_name,dept_name,dept_sub_name,purchase_method_name,purchase_method_group_name,announce_date,project_money,price_build,sum_price_agree,budget_year,transaction_date,province,district,subdistrict,project_status = [],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[]
  for i in data:
    project_id.append(i.get("project_id"))
    project_name.append(i.get("project_name"))
    project_type_name.append(i.get("project_type_name"))
    dept_name.append(i.get("dept_name"))
    dept_sub_name.append(i.get("dept_sub_name"))
    purchase_method_name.append(i.get("purchase_method_name"))
    purchase_method_group_name.append(i.get("purchase_method_group_name"))
    announce_date.append(i.get("announce_date"))
    project_money.append(i.get("project_money").replace(',',''))
    price_build.append(i.get("price_build").replace(',',''))
    sum_price_agree.append(i.get("sum_price_agree").replace(',',''))
    budget_year.append(i.get("budget_year"))
    transaction_date.append(i.get("transaction_date"))
    province.append(i.get("province"))
    district.append(i.get("district"))
    subdistrict.append(i.get("subdistrict"))
    project_status.append(i.get("project_status"))
  df = pd.DataFrame({"project_id":project_id,
                   "project_name":project_name,
                   "project_type_name":project_type_name,
                   "dept_name":dept_name,
                   "dept_sub_name":dept_sub_name,
                   "purchase_method_name":purchase_method_name,
                   "purchase_method_group_name":purchase_method_group_name,
                   "announce_date":announce_date,
                   "project_money":project_money,
                   "price_build":price_build,
                   "sum_price_agree":sum_price_agree,
                   "budget_year":budget_year,
                   "transaction_date":transaction_date,
                   "province":province,
                   "district":district,
                   "subdistrict":subdistrict,
                   "project_status":project_status
                   })
  return df

# %%
# นำข้อมูลที่ได้จากการ query แต่ละปีมาสร้างเป็น dataframe ด้วยฟังก์ชัน create_df()
df60 = create_df(data60)
df61 = create_df(data61)
df62 = create_df(data62)
df63 = create_df(data63)
df64 = create_df(data64)

# %%
#นำ dataframe ที่ได้มาต่อกัน
my_df = pd.concat([df60,df61,df62,df63,df64], axis=0)
my_df
# Out:
#        project_id                                       project_name  \
# 0     59126216244  จ้างสร้างเรือดำน้ำ (25.11.17.01 ) โดยวิธีกรณีพ...
# 1     60016013525  ประกวดราคาจ้างสร้างอาคารโครงการปรับวางที่ตั้งโ...
# 2     59045046820  เช่าระบบคอมพิวเตอร์ซอฟต์แวร์สำเร็จรูปสำหรับธุร...
# 3     60045009031  ประกวดราคาจ้างงานก่อสร้างอาคารศูนย์บริหารทางพิ...
# 4     58065138000  ประกวดราคาจ้างSupply and Construction of 500/2...
# ...           ...                                                ...
# 1048  64037173784  ประกวดราคาจ้างก่อสร้างโครงการวางท่อขยายเขตจำหน...
# 1049  64087157886  จ้างก่อสร้างนำสายไฟลงใต้ดิน เพื่อส่งเสริมสภาพพ...
# 1050  64037371910  ซื้อรถปฏิบัติการรักษาความปลอดภัยในการชุมนุม จำ...
# 1051  64057418929  ซื้อติดตั้งโคมไฟถนนพลังงานแสงอาทิตย์ขององค์การ...
# 1052  63077423041  ประกวดราคาซื้อเครื่องสูบน้ำพร้อมติดตั้งและอุปก...
#
#              project_type_name                       dept_name  \
# 0     จ้างทำของ/จ้างเหมาบริการ                      กองทัพเรือ
# 1                 จ้างก่อสร้าง                     กองทัพอากาศ
# 2                         เช่า             การไฟฟ้าส่วนภูมิภาค
# 3                 จ้างก่อสร้าง        การทางพิเศษแห่งประเทศไทย
# 4                 จ้างก่อสร้าง   การไฟฟ้าฝ่ายผลิตแห่งประเทศไทย
# ...                        ...                             ...
# 1048              จ้างก่อสร้าง  องค์การบริหารส่วนจังหวัดชลบุรี
# 1049              จ้างก่อสร้าง                      กองทัพเรือ
# 1050                      ซื้อ           สำนักงานตำรวจแห่งชาติ
# 1051                      ซื้อ  องค์การบริหารส่วนจังหวัดนครปฐม
# 1052                      ซื้อ                     กรมชลประทาน
#
#                                           dept_sub_name  \
# 0     กองทัพเรือ (สยป.ทร/งานโครงการจัดหายุทโธปกรณ์หล...
# 1                         กรมช่างโยธาทหารอากาศ กรุงเทพฯ
# 2                   การไฟฟ้าส่วนภูมิภาค (กฟภ.) กรุงเทพฯ
# 3              การทางพิเศษแห่งประเทศไทย (กทพ.) กรุงเทพฯ
# 4          การไฟฟ้าฝ่ายผลิตแห่งประเทศไทย (กฟผ.) นนทบุรี
# ...                                                 ...
# 1048                     องค์การบริหารส่วนจังหวัดชลบุรี
# 1049                       กรมช่างโยธาทหารเรือ กรุงเทพฯ
# 1050                  กองสรรพาวุธ สำนักงานส่งกำลังบำรุง
# 1051                     องค์การบริหารส่วนจังหวัดนครปฐม
# 1052                      กองพัสดุ กรมชลประทาน กรุงเทพฯ
#
#                         purchase_method_name  \
# 0                                  กรณีพิเศษ
# 1       ประกวดราคาอิเล็กทรอนิกส์ (e-bidding)
# 2                                      พิเศษ
# 3     ประกวดราคาด้วยวิธีการทางอิเล็กทรอนิกส์
# 4                                 ประกวดราคา
# ...                                      ...
# 1048    ประกวดราคาอิเล็กทรอนิกส์ (e-bidding)
# 1049                                คัดเลือก
# 1050                                คัดเลือก
# 1051                                คัดเลือก
# 1052    ประกวดราคาอิเล็กทรอนิกส์ (e-bidding)
#
#                              purchase_method_group_name announce_date  \
# 0     วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...             -
# 1     วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...    20 ม.ค. 60
# 2     วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...             -
# 3     วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...     4 พ.ค. 60
# 4     วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...   15 มิ.ย. 58
# ...                                                 ...           ...
# 1048  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...   26 มี.ค. 64
# 1049  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...             -
# 1050  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...             -
# 1051  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...             -
# 1052  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...     3 ก.ย. 63
#
#      project_money  price_build sum_price_agree budget_year transaction_date  \
# 0      13500000000  13500000000     13481863800        2560        5 พ.ค. 60
# 1       2783087000   2783087000      2690000000        2560       17 ก.ค. 60
# 2       2966724800   2752413430      2639005200        2560       11 พ.ย. 59
# 3       2985686318   2985686318      2543000000        2560       20 ก.ย. 60
# 4       3670000000   3834000000      2335644502        2560       27 ม.ค. 60
# ...            ...          ...             ...         ...              ...
# 1048      87913000     87913000        87880000        2564       20 ก.ค. 64
# 1049      88500000     88500000        87845000        2564       27 ก.ย. 64
# 1050      87950000     87950000        87800000        2564        3 ส.ค. 64
# 1051      87850000     87850000        87724500        2564      11 มิ.ย. 64
# 1052      88296000     87820250        87670000        2564      25 มี.ค. 64
#
#            province     district      subdistrict    project_status
# 0     กรุงเทพมหานคร   บางกอกใหญ่          วัดอรุณ  ระหว่างดำเนินการ
# 1     กรุงเทพมหานคร     ดอนเมือง         ดอนเมือง  ระหว่างดำเนินการ
# 2     กรุงเทพมหานคร      จตุจักร           ลาดยาว  ระหว่างดำเนินการ
# 3     กรุงเทพมหานคร       พระนคร  พระบรมมหาราชวัง  ระหว่างดำเนินการ
# 4           นนทบุรี      บางกรวย          บางกรวย  ระหว่างดำเนินการ
# ...             ...          ...              ...               ...
# 1048         ชลบุรี  เมืองชลบุรี            เสม็ด  ระหว่างดำเนินการ
# 1049  กรุงเทพมหานคร   บางกอกใหญ่          วัดอรุณ  ระหว่างดำเนินการ
# 1050  กรุงเทพมหานคร        ดุสิต     ถนนนครไชยศรี  ระหว่างดำเนินการ
# 1051         นครปฐม  เมืองนครปฐม     พระปฐมเจดีย์  ระหว่างดำเนินการ
# 1052  กรุงเทพมหานคร        ดุสิต     ถนนนครไชยศรี  ระหว่างดำเนินการ
#
# [5212 rows x 17 columns]

# %%
# create directory data
os.makedirs("data", exist_ok=True)

# %%
# export dataframe to csv into subfolder /data/
my_df.to_csv('/content/data/budget.csv')

# %% [markdown]
# ## Task 4: Load and represent the data using an appropriate data structure. Apply any pre-processing steps to clean/filter/combine the data

# %% [markdown]
# ### **อธิบายคอลัมน์**
#
# project_id	:	รหัสโครงการ
#
# project_name	:	ชื่อโครงการที่จัดซื้อจัดจ้าง
#
# project_type_name	:	ชื่อประเภทโครงการ
#
# dept_name	:	ชื่อหน่วยงาน
#
# dept_sub_name	:	ชื่อหน่วยงานย่อย
#
# purchase_method_name	:	ชื่อวิธีการจัดซื้อจัดจ้าง
#
# purchase_method_group_name	:	ชื่อกลุ่มวิธีการจัดซื้อจัดจ้าง
#
# announce_date	:	วันที่ประกาศจัดซื้อจัดจ้าง
#
# project_money	:	วงเงินงบประมาณ
#
# price_build	:	ราคากลาง
#
# sum_price_agree	:	ราคาที่ตกลงซื้อ / จ้าง ซึ่งรวมทุกสัญญาในโครงการ
#
# budget_year	:	ปีงบประมาณ
#
# transaction_date	:	วันที่เกิดรายการ
#
# province	:	ชื่อจังหวัด
#
# district	:	ชื่อเขต / อำเภอ
#
# subdistrict	:	ชื่อแขวง / ตำบล
#
# project_status	:	สถานะโครงการ

# %%
# import ข้อมูล budget.csv
df = pd.read_csv('/content/data/budget.csv')

# %%
# แสดงผลข้อมูล 20 rows แรก
df.head(20)
# Out:
#     Unnamed: 0   project_id  \
# 0            0  59126216244
# 1            1  60016013525
# 2            2  59045046820
# 3            3  60045009031
# 4            4  58065138000
# 5            5  60076079396
# 6            6  59096215317
# 7            7  59096233814
# 8            8  59116272226
# 9            9  59096225619
# 10          10  59096242846
# 11          11  59096223148
# 12          12  59096226638
# 13          13  59096226116
# 14          14  59096252977
# 15          15  59096175086
# 16          16  59096024329
# 17          17  59096256388
# 18          18  59096077445
ิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...             -
# 1   วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...    20 ม.ค. 60
# 2   วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...             -
# 3   วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...     4 พ.ค. 60
# 4   วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...   15 มิ.ย. 58
# 5   วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...             -
# 6   วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...    27 ก.ย. 59
# 7   วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...    27 ก.ย. 59
# 8   วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...     7 ธ.ค. 59
# 9   วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...    26 ก.ย. 59
# 10  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...    28 ก.ย. 59
# 11  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...    27 ก.ย. 59
# 12  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...    26 ก.ย. 59
# 13  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...    26 ก.ย. 59
# 14  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...    29 ก.ย. 59
# 15  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...    26 ก.ย. 59
# 16  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...     8 ก.ย. 59
# 17  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...    29 ก.ย. 59
# 18  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...    20 ก.ย. 59
# 19  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...     1 พ.ย. 59
#
#     project_money  price_build  sum_price_agree  budget_year transaction_date  \
# 0     13500000000  13500000000      13481863800         2560        5 พ.ค. 60
# 1      2783087000   2783087000       2690000000         2560       17 ก.ค. 60
# 2      2966724800   2752413430       2639005200         2560       11 พ.ย. 59
# 3      2985686318   2985686318       2543000000         2560       20 ก.ย. 60
# 4      3670000000   3834000000       2335644502         2560       27 ม.ค. 60
# 5      2126073600   2126073600       2116000000         2560       11 ก.ค. 60
# 6      2000000000   1999985104       1994000000         2560      15 มี.ค. 60
# 7      2000000000   1987676075       1981700000         2560      15 มี.ค. 60
# 8      2000000000   1943492188       1938840000         2560      12 เม.ย. 60
# 9      2000000000   1932436048       1926299000         2560      15 มี.ค. 60
# 10     1935000000   1916864318       1911113000         2560       20 ก.พ. 60
# 11     1860000000   1856071338       1850470000         2560       26 ก.ค. 60
# 12     2000000000   1824739305       1815576000         2560      15 มี.ค. 60
# 13     1990000000   1766280996       1760610000         2560      15 มี.ค. 60
# 14     1850000000   1732274859       1727078000         2560      20 มี.ค. 60
# 15     2015000000   1726959548       1721780000         2560       20 ก.พ. 60
# 16     2050000000   1706983215       1701860000         2560       20 ก.พ. 60
# 17     1926000000   1695275022       1684477000         2560        1 ก.ย. 60
# 18     1966000000   1831723000       1680000000         2560      29 มี.ค. 60
# 19     2600000000   2589931657       1650000000         2560       22 พ.ค. 60
#
#          province    district      subdistrict    project_status
# 0   กรุงเทพมหานคร  บางกอกใหญ่          วัดอรุณ  ระหว่างดำเนินการ
# 1   กรุงเทพมหานคร    ดอนเมือง         ดอนเมือง  ระหว่างดำเนินการ
# 2   กรุงเทพมหานคร     จตุจักร           ลาดยาว  ระหว่างดำเนินการ
# 3   กรุงเทพมหานคร      พระนคร  พระบรมมหาราชวัง  ระหว่างดำเนินการ
# 4         นนทบุรี     บางกรวย          บางกรวย  ระหว่างดำเนินการ
# 5   กรุงเทพมหานคร       ดุสิต     ถนนนครไชยศรี  ระหว่างดำเนินการ
# 6   กรุงเทพมหานคร     ราชเทวี        ทุ่งพญาไท  ระหว่างดำเนินการ
# 7   กรุงเทพมหานคร     ราชเทวี        ทุ่งพญาไท  ระหว่างดำเนินการ
# 8   กรุงเทพมหานคร     ราชเทวี        ทุ่งพญาไท  ระหว่างดำเนินการ
# 9   กรุงเทพมหานคร     ราชเทวี        ทุ่งพญาไท  ระหว่างดำเนินการ
# 10  กรุงเทพมหานคร     ราชเทวี        ทุ่งพญาไท  ระหว่างดำเนินการ
# 11  กรุงเทพมหานคร     ราชเทวี        ทุ่งพญาไท  ระหว่างดำเนินการ
# 12  กรุงเทพมหานคร     ราชเทวี        ทุ่งพญาไท  ระหว่างดำเนินการ
# 13  กรุงเทพมหานคร     ราชเทวี        ทุ่งพญาไท  ระหว่างดำเนินการ
# 14  กรุงเทพมหานคร     ราชเทวี        ทุ่งพญาไท  ระหว่างดำเนินการ
# 15  กรุงเทพมหานคร     ราชเทวี        ทุ่งพญาไท  ระหว่างดำเนินการ
# 16  กรุงเทพมหานคร     ราชเทวี        ทุ่งพญาไท  ระหว่างดำเนินการ
# 17  กรุงเทพมหานคร     ราชเทวี        ทุ่งพญาไท  ระหว่างดำเนินการ
# 18  กรุงเทพมหานคร       พญาไท         สามเสนใน  ระหว่างดำเนินการ
# 19  กรุงเทพมหานคร       ดุสิต     ถนนนครไชยศรี  ระหว่างดำเนินการ

# %%
# ดูชื่อคอลัมน์, ค่า null, ประเภทของข้อมูลทั้งหมด
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5212 entries, 0 to 5211
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  5212 non-null   int64
#  1   project_id                  5212 non-null   int64
#  2   project_name                5212 non-null   object
#  3   project_type_name           5212 non-null   object
#  4   dept_name                   5212 non-null   object
#  5   dept_sub_name               5212 non-null   object
#  6   purchase_method_name        5212 non-null   object
#  7   purchase_method_group_name  5212 non-null   object
#  8   announce_date               5212 non-null   object
#  9   project_money               5212 non-null   int64
#  10  price_build                 5212 non-null   int64
#  11  sum_price_agree             5212 non-null   int64
#  12  budget_year                 5212 non-null   int64
#  13  transaction_date            5212 non-null   object
#  14  province                    5212 non-null   object
#  15  district                    5212 non-null   object
#  16  subdistrict                 5212 non-null   object
#  17  project_status              5212 non-null   object
# dtypes: int64(6), object(12)
# memory usage: 733.1+ KB

# %%
# หาค่าสถิติเบื้องต้นของข้อมูล
df.describe()
# Out:
#        Unnamed: 0         project_id      project_money        price_build  \
# count 5212.000000        5212.000000        5212.000000        5212.000000
# mean   520.828281 61502257025.337296   414447449.453761   406591152.021873
# std    301.164767  1541944200.031056  1837237154.878332  1806546429.348057
# min      0.000000 57065276759.000000    31651298.000000           8.000000
# 25%    260.000000 60086144736.500000   100000000.000000    99796628.000000
# 50%    521.000000 61117114379.000000   158110584.000000   154132997.500000
# 75%    781.000000 63037564204.500000   330000000.000000   322692458.500000
# max   1059.000000 64216000006.000000 97572658000.000000 97572658000.000000
#
#          sum_price_agree  budget_year
# count        5212.000000  5212.000000
# mean    365220068.126247  2562.019570
# std    1678601760.736669     1.410681
# min      55779983.000000  2560.000000
# 25%      96262221.250000  2561.000000
# 50%     143068525.000000  2562.000000
# 75%     291119857.500000  2563.000000
# max   97572658000.000000  2564.000000

# %%
# drop column Unnamed: 0 ทิ้ง
df = df.drop(["Unnamed: 0"], axis=1)

# %%
# เปลี่ยนประเภทของข้อมูลที่เป็น object ให้เป็น string
df['project_name'] = df['project_name'].astype("string")
df['project_type_name'] = df['project_type_name'].astype("string")
df['dept_name'] = df['dept_name'].astype("string")
df['dept_sub_name'] = df['dept_sub_name'].astype("string")
df['dept_sub_name'] = df['dept_sub_name'].astype("string")
df['purchase_method_name'] = df['purchase_method_name'].astype("string")
df['purchase_method_group_name'] = df['purchase_method_group_name'].astype("string")
df['announce_date'] = df['announce_date'].astype("string")
df['price_build'] = df['price_build'].astype("string")
df['budget_year'] = df['budget_year'].astype("string")
df['transaction_date'] = df['transaction_date'].astype("string")
df['province'] = df['province'].astype("string")
df['district'] = df['district'].astype("string")
df['subdistrict'] = df['subdistrict'].astype("string")
df['project_status'] = df['project_status'].astype("string")

# %%
# ดูจำนวนของข้อมูลแต่ละประเภท
df.dtypes.value_counts()
# Out:
# string    14
# int64      3
# dtype: int64

# %%
# เปลี่ยนค่าของข้อมูลที่ขาดหายไปซึ่งก็คือ - ให้เป็นค่า 0
df['announce_date'] = df['announce_date'].replace("-","0")

# %%
# เช็คข้อมูลดูอีกรอบ
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5212 entries, 0 to 5211
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   project_id                  5212 non-null   int64
#  1   project_name                5212 non-null   string
#  2   project_type_name           5212 non-null   string
#  3   dept_name                   5212 non-null   string
#  4   dept_sub_name               5212 non-null   string
#  5   purchase_method_name        5212 non-null   string
#  6   purchase_method_group_name  5212 non-null   string
#  7   announce_date               5212 non-null   string
#  8   project_money               5212 non-null   int64
#  9   price_build                 5212 non-null   string
#  10  sum_price_agree             5212 non-null   int64
#  11  budget_year                 5212 non-null   string
#  12  transaction_date            5212 non-null   string
#  13  province                    5212 non-null   string
#  14  district                    5212 non-null   string
#  15  subdistrict                 5212 non-null   string
#  16  project_status              5212 non-null   string
# dtypes: int64(3), string(14)
# memory usage: 692.3 KB

# %%
# เปลี่ยน announce_date ให้เป็นปีพ.ศ.อย่างเดียว
announce_convert = []
for i in range(len(df)):
  if df['announce_date'][i] != "0":
    year = df['announce_date'][i].split(' ')[-1]
    announce_convert.append(int("25"+year))
  else:
    announce_convert.append(0)

df['announce_date'] = announce_convert

# %%
# เปลี่ยน transaction_date ให้เป็นปีพ.ศ.อย่างเดียว
transaction_convert = []
for i in range(len(df)):
  if df['transaction_date'][i] != "0":
    year = df['transaction_date'][i].split(' ')[-1]
    transaction_convert.append(int("25"+year))
  else:
    transaction_convert.append(0)

df['transaction_date'] = transaction_convert

# %%
# ดูค่าสถิติของข้อมูล
df.describe()
# Out:
#               project_id  announce_date      project_money    sum_price_agree  \
# count        5212.000000    5212.000000        5212.000000        5212.000000
# mean  61502257025.337296    1963.833845   414447449.453761   365220068.126247
# std    1541944200.031056    1083.429915  1837237154.878332  1678601760.736669
# min   57065276759.000000       0.000000    31651298.000000    55779983.000000
# 25%   60086144736.500000    2559.000000   100000000.000000    96262221.250000
# 50%   61117114379.000000    2561.000000   158110584.000000   143068525.000000
# 75%   63037564204.500000    2562.000000   330000000.000000   291119857.500000
# max   64216000006.000000    2564.000000 97572658000.000000 97572658000.000000
#
#        transaction_date
# count       5212.000000
# mean        2561.806984
# std            1.473480
# min         2559.000000
# 25%         2560.000000
# 50%         2562.000000
# 75%         2563.000000
# max         2564.000000

# %% [markdown]
# ## Task 5: Analyse and summarise the cleaned dataset

# %%
cleandf = df
cleandf
# Out:
#        project_id                                       project_name  \
# 0     59126216244  จ้างสร้างเรือดำน้ำ (25.11.17.01 ) โดยวิธีกรณีพ...
# 1     60016013525  ประกวดราคาจ้างสร้างอาคารโครงการปรับวางที่ตั้งโ...
# 2     59045046820  เช่าระบบคอมพิวเตอร์ซอฟต์แวร์สำเร็จรูปสำหรับธุร...
# 3     60045009031  ประกวดราคาจ้างงานก่อสร้างอาคารศูนย์บริหารทางพิ...
# 4     58065138000  ประกวดราคาจ้างSupply and Construction of 500/2...
# ...           ...                                                ...
# 5207  64037173784  ประกวดราคาจ้างก่อสร้างโครงการวางท่อขยายเขตจำหน...
# 5208  64087157886  จ้างก่อสร้างนำสายไฟลงใต้ดิน เพื่อส่งเสริมสภาพพ...
# 5209  64037371910  ซื้อรถปฏิบัติการรักษาความปลอดภัยในการชุมนุม จำ...
# 5210  64057418929  ซื้อติดตั้งโคมไฟถนนพลังงานแสงอาทิตย์ขององค์การ...
# 5211  63077423041  ประกวดราคาซื้อเครื่องสูบน้ำพร้อมติดตั้งและอุปก...
#
#              project_type_name                       dept_name  \
# 0     จ้างทำของ/จ้างเหมาบริการ                      กองทัพเรือ
# 1                 จ้างก่อสร้าง                     กองทัพอากาศ
# 2                         เช่า             การไฟฟ้าส่วนภูมิภาค
# 3                 จ้างก่อสร้าง        การทางพิเศษแห่งประเทศไทย
# 4                 จ้างก่อสร้าง   การไฟฟ้าฝ่ายผลิตแห่งประเทศไทย
# ...                        ...                             ...
# 5207              จ้างก่อสร้าง  องค์การบริหารส่วนจังหวัดชลบุรี
# 5208              จ้างก่อสร้าง                      กองทัพเรือ
# 5209                      ซื้อ           สำนักงานตำรวจแห่งชาติ
# 5210                      ซื้อ  องค์การบริหารส่วนจังหวัดนครปฐม
# 5211                      ซื้อ                     กรมชลประทาน
#
#                                           dept_sub_name  \
# 0     กองทัพเรือ (สยป.ทร/งานโครงการจัดหายุทโธปกรณ์หล...
# 1                         กรมช่างโยธาทหารอากาศ กรุงเทพฯ
# 2                   การไฟฟ้าส่วนภูมิภาค (กฟภ.) กรุงเทพฯ
# 3              การทางพิเศษแห่งประเทศไทย (กทพ.) กรุงเทพฯ
# 4          การไฟฟ้าฝ่ายผลิตแห่งประเทศไทย (กฟผ.) นนทบุรี
# ...                                                 ...
# 5207                     องค์การบริหารส่วนจังหวัดชลบุรี
# 5208                       กรมช่างโยธาทหารเรือ กรุงเทพฯ
# 5209                  กองสรรพาวุธ สำนักงานส่งกำลังบำรุง
# 5210                     องค์การบริหารส่วนจังหวัดนครปฐม
# 5211                      กองพัสดุ กรมชลประทาน กรุงเทพฯ
#
#                         purchase_method_name  \
# 0                                  กรณีพิเศษ
# 1       ประกวดราคาอิเล็กทรอนิกส์ (e-bidding)
# 2                                      พิเศษ
# 3     ประกวดราคาด้วยวิธีการทางอิเล็กทรอนิกส์
# 4                                 ประกวดราคา
# ...                                      ...
# 5207    ประกวดราคาอิเล็กทรอนิกส์ (e-bidding)
# 5208                                คัดเลือก
# 5209                                คัดเลือก
# 5210                                คัดเลือก
# 5211    ประกวดราคาอิเล็กทรอนิกส์ (e-bidding)
#
#                              purchase_method_group_name  announce_date  \
# 0     วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...              0
# 1     วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...           2560
# 2     วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...              0
# 3     วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...           2560
# 4     วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...           2558
# ...                                                 ...            ...
# 5207  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...           2564
# 5208  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...              0
# 5209  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...              0
# 5210  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...              0
# 5211  วิธีการจัดหา ประกาศเชิญชวนทั่วไป คัดเลือก เฉพา...           2563
#
#       project_money  price_build  sum_price_agree budget_year  \
# 0       13500000000  13500000000      13481863800        2560
# 1        2783087000   2783087000       2690000000        2560
# 2        2966724800   2752413430       2639005200        2560
# 3        2985686318   2985686318       2543000000        2560
# 4        3670000000   3834000000       2335644502        2560
# ...             ...          ...              ...         ...
# 5207       87913000     87913000         87880000        2564
# 5208       88500000     88500000         87845000        2564
# 5209       87950000     87950000         87800000        2564
# 5210       87850000     87850000         87724500        2564
# 5211       88296000     87820250         87670000        2564
#
#       transaction_date       province     district      subdistrict  \
# 0                 2560  กรุงเทพมหานคร   บางกอกใหญ่          วัดอรุณ
# 1                 2560  กรุงเทพมหานคร     ดอนเมือง         ดอนเมือง
# 2                 2559  กรุงเทพมหานคร      จตุจักร           ลาดยาว
# 3                 2560  กรุงเทพมหานคร       พระนคร  พระบรมมหาราชวัง
# 4                 2560        นนทบุรี      บางกรวย          บางกรวย
# ...                ...            ...          ...              ...
# 5207              2564         ชลบุรี  เมืองชลบุรี            เสม็ด
# 5208              2564  กรุงเทพมหานคร   บางกอกใหญ่          วัดอรุณ
# 5209              2564  กรุงเทพมหานคร        ดุสิต     ถนนนครไชยศรี
# 5210              2564         นครปฐม  เมืองนครปฐม     พระปฐมเจดีย์
# 5211              2564  กรุงเทพมหานคร        ดุสิต     ถนนนครไชยศรี
#
#         project_status
# 0     ระหว่างดำเนินการ
# 1     ระหว่างดำเนินการ
# 2     ระหว่างดำเนินการ
# 3     ระหว่างดำเนินการ
# 4     ระหว่างดำเนินการ
# ...                ...
# 5207  ระหว่างดำเนินการ
# 5208  ระหว่างดำเนินการ
# 5209  ระหว่างดำเนินการ
# 5210  ระหว่างดำเนินการ
# 5211  ระหว่างดำเนินการ
#
# [5212 rows x 17 columns]

# %%
cleandf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5212 entries, 0 to 5211
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   project_id                  5212 non-null   int64
#  1   project_name                5212 non-null   string
#  2   project_type_name           5212 non-null   string
#  3   dept_name                   5212 non-null   string
#  4   dept_sub_name               5212 non-null   string
#  5   purchase_method_name        5212 non-null   string
#  6   purchase_method_group_name  5212 non-null   string
#  7   announce_date               5212 non-null   int64
#  8   project_money               5212 non-null   int64
#  9   price_build                 5212 non-null   string
#  10  sum_price_agree             5212 non-null   int64
#  11  budget_year                 5212 non-null   string
#  12  transaction_date            5212 non-null   int64
#  13  province                    5212 non-null   string
#  14  district                    5212 non-null   string
#  15  subdistrict                 5212 non-null   string
#  16  project_status              5212 non-null   string
# dtypes: int64(5), string(12)
# memory usage: 692.3 KB

# %% [markdown]
# ## ปีที่ใช้งบประมาณมากที่สุด

# %%
# หางบประมาณทั้งหมดที่ใช้ในแต่ละปี
sum_bg = cleandf[['sum_price_agree','budget_year']]
sum_bg = sum_bg.groupby(by=['budget_year'], as_index=False).sum()
sum_bg
# Out:
#   budget_year  sum_price_agree
# 0        2560     263606662570
# 1        2561     283454806276
# 2        2562     420945041887
# 3        2563     409941322955
# 4        2564     525579161386

# %%
# plot line chart งบประมาณที่ใช้ตั้งแต่ปี 2560-2564
fig = px.line(sum_bg, x="budget_year", y="sum_price_agree", title='งบประมาณที่ใช้ในแต่ละปี')
fig.update_traces(mode="markers+lines")
fig.update_layout(
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="Rockwell"
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="62e2104b-89c5-4cf1-ba49-f7a2ff0c7d36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62e2104b-89c5-4cf1-ba49-f7a2ff0c7d36")) {                    Plotly.newPlot(                        "62e2104b-89c5-4cf1-ba49-f7a2ff0c7d36",                        [{"hovertemplate":"budget_year=%{x}<br>sum_price_agree=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":["2560","2561","2562","2563","2564"],"xaxis":"x","y":[263606662570,283454806276,420945041887,409941322955,525579161386],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"sc ...

# %% [markdown]
# จากกราฟจะเห็นว่าปี 2564 เป็นปีที่ใช้งบประมาณมากที่สุด

# %% [markdown]
# ## งบประมาณโครงการทั้งหมดที่ใช้ในแต่ละจังหวัดในปี2564

# %%
# หางบประมาณที่ใช้ในแต่ละจังหวัด
sum_pv = cleandf[cleandf['budget_year'] == '2564']
sum_pv = sum_pv[['sum_price_agree','province']]
sum_pv = sum_pv.groupby(by=['province'],as_index=False).sum()
sum_pv
# Out:
#            province  sum_price_agree
# 0     กรุงเทพมหานคร     482649320415
# 1         กาฬสินธุ์        211611800
# 2           ขอนแก่น        651104200
# 3            ชลบุรี       2968604242
# 4            ชัยนาท         99888600
# 5           ชัยภูมิ        105600000
# 6              ตรัง        149900000
# 7           นครนายก        148817000
# 8            นครปฐม        577925768
# 9            นครพนม        197920000
# 10       นครราชสีมา        679046587
# 11    นครศรีธรรมราช       1439086670
# 12          นนทบุรี      12187539985
# 13        บุรีรัมย์        390713139
# 14         ปทุมธานี        340562705
# 15  ประจวบคีรีขันธ์        329908888
# 16          ปัตตานี        439334000
# 17           พัทลุง        161246509
# 18         พิษณุโลก        663377038
# 19           ภูเก็ต       1257395375
# 20        มหาสารคาม        424340000
# 21             ยะลา        394810000
# 22            ระยอง        947029277
# 23          ราชบุรี        379424216
# 24         ร้อยเอ็ด        281800000
# 25           ลพบุรี        128708802
# 26            สงขลา        919660000
# 27      สมุทรปราการ       8718597180
# 28        สมุทรสาคร        483400000
# 29          สระบุรี        578513875
# 30       สุพรรณบุรี        116500000
# 31     สุราษฎร์ธานี        158429333
# 32         สุรินทร์        145400000
# 33          หนองคาย        130000000
# 34         อุดรธานี       1898353560
# 35        อุตรดิตถ์        623917888
# 36      อุบลราชธานี        448500000
# 37         เชียงราย        736614480
# 38        เชียงใหม่       1259424854
# 39         เพชรบุรี        147800000
# 40        เพชรบูรณ์        344150000
# 41              เลย        124885000
# 42             แพร่        540000000

# %%
# plot tree map งบประมาณที่ใช้ในแต่ละจังหวัด
colors=['#fae588','#f79d65','#f9dc5c','#e8ac65','#e76f51','#ef233c','#b7094c']
fig = px.treemap(sum_pv, path=['province'],values='sum_price_agree', width=900, height=600, title="งบประมาณที่ใช้ในแต่ละจังหวัดปี2564")
fig.update_layout(
    treemapcolorway = colors,
    margin = dict(t=50, l=25, r=25, b=25))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8af959c3-9893-4c5c-a059-470380678d76" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8af959c3-9893-4c5c-a059-470380678d76")) {                    Plotly.newPlot(                        "8af959c3-9893-4c5c-a059-470380678d76",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>sum_price_agree=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["\u0e01\u0e23\u0e38\u0e07\u0e40\u0e17\u0e1e\u0e21\u0e2b\u0e32\u0e19\u0e04\u0e23","\u0e01\u0e32\u0e2c\u0e2a\u0e34\u0e19\u0e18\u0e38\u0e4c","\u0e02\u0e2d\u0e19\u0e41\u0e01\u0e48\u0e19","\u0e0a\u0e25\u0e1a\u0e38\u0e23\u0e35","\u0e0a\u0e31\u0e22\u0e19\u0e32\u0e17","\u0e0a\u0e31\u0e22\u0e20\u0e39\u0e21\u0e34","\u0e15\u0e23\u0e31\u0e07","\u0e19\u0e04\u0e23\u0e19\u0e32\u0e22\u0e01","\u0e19\u0e04\u0e23\u0e1b\u0e10\u0e21","\u0e19\u0e04\u0e23\u0e1e\u0e19\u0e21","\u0e19\u0e04\u0e23\u0e23\u0e32\u0e0a\u0e2a\u0e35\u0e21\u0e32","\u0e19\u0e04\u0e23\u0e28\u0e23\u0e35\u0e18\u0e23\u0e23\u0e21\u0e23\u0e32\u0e0a","\u0e19\u0e19\u0e17\u0e1a\u0e38\u0e23\u0e35","\u0e1a\u0e38\u0e23\u0e35\u0e23\u0e31\u0e21\u0e22\u0e4c","\u0e1b\u0e17\u0e38\u0e21\u0e18\u0e32\u0e19\u0e35","\u0e1b\u0e23\u0e30\u0e08\u0e27\u0e1a\u0e04\u0e35\u0e23\u0e35\u0e02\u0e31\u0e19\u0e18\u0e4c","\u0e1b\u0e31\u0e15\u0e15\u0e32\u0e19\u0e35","\u0e1e\u0e31\u0e17\u0e25\u0e38\u0e07","\u0e1e\u0e34\u0e29\u0e13\u0e38\u0e42\u0e25\u0e01","\u0e20\u0e39\u0e40\u0e01\u0e47\u0e15","\u0e21\u0e2b\u0e32\u0e2a\u0e32\u0e23\u
4c","\u0e1b\u0e17\u0e38\u0e21\u0e18\u0e32\u0e19\u0e35","\u0e1b\u0e23\u0e30\u0e08\u0e27\u0e1a\u0e04\u0e35\u0e23\u0e35\u0e02\u0e31\u0e19\u0e18\u0e4c","\u0e1b\u0e31\u0e15\u0e15\u0e32\u0e19\u0e35","\u0e1e\u0e31\u0e17\u0e25\u0e38\u0e07","\u0e1e\u0e34\u0e29\u0e13\u0e38\u0e42\u0e25\u0e01","\u0e20\u0e39\u0e40\u0e01\u0e47\u0e15","\u0e21\u0e2b\u0e32\u0e2a\u0e32\u0e23\u0e04\u0e32\u0e21","\u0e22\u0e30\u0e25\u0e32","\u0e23 ...

# %% [markdown]
# จากกราฟจะเห็นว่าจังหวัดกรุงเทพมหานครมีการใช้งบประมาณมากที่สุดในปี 2564

# %% [markdown]
# ## งบประมาณที่ใช้แต่ละหน่วยงานในจังหวัดกรุงทพมหานครปี2564

# %%
# หางบประมาณที่แต่ละหน่วยงานใช้
sum_dept = cleandf[(cleandf['budget_year'] == '2564') & (cleandf['province']=='กรุงเทพมหานคร')]
sum_dept = sum_dept[['dept_name','sum_price_agree']]
sum_dept = sum_dept.groupby(by=['dept_name'],as_index=False).sum()
sum_dept
# Out:
#                                 dept_name  sum_price_agree
# 0                        กรมการขนส่งทางบก        493005700
# 1                              กรมการข้าว       1435699888
# 2                            กรมการปกครอง       2560019350
# 3                             กรมชลประทาน      20624541560
# 4                          กรมทรัพยากรน้ำ        462900000
# ..                                    ...              ...
# 97            องค์การสงเคราะห์ทหารผ่านศึก         94274395
# 98                       องค์การเภสัชกรรม       2145730045
# 99                 โรงพยาบาลพระมงกุฎเกล้า        180000000
# 100                      โรงพยาบาลราชวิถี      12563350381
# 101  โรงพยาบาลรามาธิบดี  มหาวิทยาลัยมหิดล       1256333920
#
# [102 rows x 2 columns]

# %%
# เลือกหน่วยงาน10อันดับแรกที่ใช้งบเยอะที่สุด
sum_dept = sum_dept.sort_values(by="sum_price_agree", ascending=False).head(10)
sum_dept
# Out:
#                    dept_name  sum_price_agree
# 39      การรถไฟแห่งประเทศไทย     158325297409
# 6                 กรมทางหลวง      56269475913
# 26             กรุงเทพมหานคร      43834200992
# 42       การไฟฟ้าส่วนภูมิภาค      21721257614
# 3                กรมชลประทาน      20624541560
# 36           การประปานครหลวง      18648855470
# 25   กรมโยธาธิการและผังเมือง      17899698400
# 41           การไฟฟ้านครหลวง      16717447742
# 78     สำนักงานตำรวจแห่งชาติ      14983282949
# 100         โรงพยาบาลราชวิถี      12563350381

# %%
fig = px.bar(sum_dept, x='dept_name', y='sum_price_agree', title="10อันดับหน่วยงานแรกที่ใช้งบประมาณมากที่สุดของกรุงเทพมหานคร ปี 2564")
fig.update_layout(
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="Rockwell"
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bf5d025b-da4a-484e-8ba5-17197d65431a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf5d025b-da4a-484e-8ba5-17197d65431a")) {                    Plotly.newPlot(                        "bf5d025b-da4a-484e-8ba5-17197d65431a",                        [{"alignmentgroup":"True","hovertemplate":"dept_name=%{x}<br>sum_price_agree=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\u0e01\u0e32\u0e23\u0e23\u0e16\u0e44\u0e1f\u0e41\u0e2b\u0e48\u0e07\u0e1b\u0e23\u0e30\u0e40\u0e17\u0e28\u0e44\u0e17\u0e22","\u0e01\u0e23\u0e21\u0e17\u0e32\u0e07\u0e2b\u0e25\u0e27\u0e07","\u0e01\u0e23\u0e38\u0e07\u0e40\u0e17\u0e1e\u0e21\u0e2b\u0e32\u0e19\u0e04\u0e23","\u0e01\u0e32\u0e23\u0e44\u0e1f\u0e1f\u0e49\u0e32\u0e2a\u0e48\u0e27\u0e19\u0e20\u0e39\u0e21\u0e34\u0e20\u0e32\u0e04","\u0e01\u0e23\u0e21\u0e0a\u0e25\u0e1b\u0e23\u0e30\u0e17\u0e32\u0e19","\u0e01\u0e32\u0e23\u0e1b\u0e23\u0e30\u0e1b\u0e32\u0e19\u0e04\u0e23\u0e2b\u0e25\u0e27\u0e07","\u0e01\u0e23\u0e21\u0e42\u0e22\u0e18\u0e32\u0e18\u0e34\u0e01\u0e32\u0e23\u0e41\u0e25\u0e30\u0e1c\u0e31\u0e07\u0e40\u0e21\u0e37\u0e2d\u0e07","\u0e01\u0e32\u0e23\u0e44\u0e1f\u0e1f\u0e49\u0e32\u0e19\u0e04\u0e23\u0e2b\u0e25\u0e27\u0e07","\u0e2a\u0e33\u0e19\u0e31\u0e01\u0e07\u0e32\u0e19\u0e15\u0e33\u0e23\u0e27\u0e08\u0e41\u0e2b\u0e48\u0e07\u0e0a\u0e32\u0e15\u0e34","\u0e42\u0e23\u0e07\u0e1e\u0e22\u0e32\u0e1a\u0e32\u0e25\u0e23\u0e32\u0e0a\u0e27\u0e34\u0e16\u0e35"],"xaxis":"x","y":[158325297409,56269475913,43834200992,21721257614,20624541560,18648855470,17899698400,16717447742,14983282949,12563350381],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"his ...

# %% [markdown]
# จากกราฟจะเห็นว่าการรถไฟแห่งประเทศไทยมีการใช้งบประมาณมากที่สุดในจังหวัดกรุงเทพมหานครปี2564

# %% [markdown]
# ## งบประมาณที่ใช้ทั้งหมดปี2564ของจังหวัดกรุงเทพมหานครในแต่ละเขต

# %%
sum_dt = cleandf[(cleandf['budget_year'] == '2564') & (cleandf['province']=='กรุงเทพมหานคร')]
sum_dt = sum_dt[['district','sum_price_agree']]
sum_dt = sum_dt.groupby(by=['district'],as_index=False).sum()
sum_dt
# Out:
#        district  sum_price_agree
# 0             -       3358220673
# 1       คลองเตย      10641554966
# 2       จตุจักร      34463447021
# 3      ดอนเมือง       2352853637
# 4        ดินแดง      43623620984
# 5         ดุสิต      42077470566
# 6       ทุ่งครุ        394600000
# 7    บางกอกน้อย        525443450
# 8    บางกอกใหญ่       5078003555
# 9       บางกะปิ        699550000
# 10      บางซื่อ       3423794600
# 11        บางนา        542114400
# 12       บางรัก         95303627
# 13       บางเขน       8007667458
2d\u0e01\u0e19\u0e49\u0e2d\u0e22","\u0e1a\u0e32\u0e07\u0e01\u0e2d\u0e01\u0e43\u0e2b\u0e0d\u0e48","\u0e1a\u0e32\u0e07\u0e01\u0e30\u0e1b\u0e34","\u0e1a\u0e32\u0e07\u0e0b\u0e37\u0e48\u0e2d","\u0e1a\u0e32\u0e07\u0e19\u0e32","\u0e1a\u0e32\u0e07\u0e23\u0e31\u0e01","\u0e1a\u0e32\u0e07\u0e40\u0e02\u0e19","\u0e1b\u0e17\u0e38\u0e21\u0e27\u0e31\u0e19","\u0e1e\u0e0d\u0e32\u0e44\u0e17","\u0e1e\u0e23\u0e30\u0e19\u0e04\u0e23","\u0e23\u0e32\u0e0a\u0e40\u0e17\u0e27\u0e35","\u0e25\u0e32\u0e14\u0e01\u0e23\u0e30\u0e1a\u0e31\u0e07","\u0e27\u0e31\u0e12\u0e19\u0e32","\u0e2a\u0e31\u0e21\u0e1e\u0e31\u0e19\u0e18\u0e27\u0e07\u0e28\u0e4c","\u0e2a\u0e32\u0e17\u0e23","\u0e2b\u0e25\u0e31\u0e01\u0e2a\u0e35\u0e48","\u0e2b\u0e49\u0e27\u0e22\u0e02\u0e27\u0e32\u0e07"],"name":"","parents":["","","","","","","","","","","","","","","","","","","","","","","",""],"values":[3358220673,10641554966,34463447021,2352853637,43623620984,42077470566,394600000,525443450,5078003555,699550000,3423794600,542114400,95303627,8007667458,161199079713,20748553381,28970849389,76342593570,682483682,118000000,1541600000,7330650180,30070878351,360987212],"type":"treemap"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[ ...

# %% [markdown]
# จากกราฟจะเห็นว่าเขตประทุมวันมีการใช้งบประมาณมากที่สุดในปี 2564

# %% [markdown]
# ## งบประมาณแต่ละโครงการในเขตประทุมวันปี2564

# %%
# หางบประมาณที่ใช้ในแต่ละโครงการ
sum_pj = cleandf[(cleandf['budget_year'] == '2564') & (cleandf['province']=='กรุงเทพมหานคร') & (cleandf['district']=='ปทุมวัน')]
sum_pj = sum_pj[['project_name','sum_price_agree']]
sum_pj = sum_pj.groupby(by=['project_name'],as_index=False).sum()
sum_pj
# Out:
#                                          project_name  sum_price_agree
# 0   จ้างการจัดจ้างบริการสื่อสารและโทรคมนาคม โครงกา...        328999080
# 1   จ้างก่อสร้างปรับปรุงโครงการพัฒนาศูนย์ความเป็นเ...        129882324
# 2   จ้างบริหารการเดินรถไฟฟ้า ระบบขนส่งทางรถไฟเชื่อ...        329181297
# 3   ซื้อเครื่องมือพิเศษเพื่อเพิ่มประสิทธิภาพการสืบ...        239290000
# 4   ซื้อโครงการเพิ่มประสิทธิภาพในการสืบสวนอาชญากรร...        467400000
# 5   ประกวดราคาจ้างก่อสร้างจ้างก่อสร้างอาคารเรียนสา...        479479000
# 6   ประกวดราคาจ้างก่อสร้างจ้างตกแต่งภายในและงานระบ...        298400000
# 7   ประกวดราคาจ้างก่อสร้างปรับปรุงประสิทธิภาพและเพ...        113153900
# 8   ประกวดราคาจ้างก่อสร้างฝาย อาคารโรงไฟฟ้า ระบบส่...        112678000
# 9   ประกวดราคาจ้างก่อสร้างออกแบบ จัดหาและติดตั้งระ...        425000000
# 10  ประกวดราคาจ้างก่อสร้างโครงการก่อสร้างทางเชื่อม...        476440000
# 11  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...      19696000000
# 12  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...      21140000000
# 13  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...      23050701000
# 14  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...      13146000000
# 15  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...      18857999938
# 16  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...       8558618780
# 17  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...      19675994794
# 18  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...      15500000000
# 19  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...      17120000000
# 20  ประกวดราคาจ้างทำความสะอาดอาคารและบริเวณสถานีรถ...        179421600
# 21  ประกวดราคาจ้างบริการรักษาความปลอดภัยและจัดการจ...        169940000
# 22  ประกวดราคาซื้อจัดซื้อที่ดินเพื่อก่อสร้างสำนักง...        320000000
# 23  ประกวดราคาซื้อเครื่องตรวจวัดแอลกอฮอล์ แบบยืนยั...        199800000
# 24  ประกวดราคาซื้อโครงการปรับปรุงเครื่องคอมพิวเตอร...         95900000
# 25  ประกวดราคาซื้อโครงการวิเคราะห์และเฝ้าระวังในกา...         88800000

# %%
sum_pj = sum_pj.sort_values(by="sum_price_agree", ascending=False).head(10)
sum_pj
# Out:
#                                          project_name  sum_price_agree
# 13  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...      23050701000
# 12  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...      21140000000
# 11  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...      19696000000
# 17  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...      19675994794
# 15  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...      18857999938
# 19  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...      17120000000
# 18  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...      15500000000
# 14  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...      13146000000
# 16  ประกวดราคาจ้างก่อสร้างโครงการความร่วมมือระหว่า...       8558618780
# 5   ประกวดราคาจ้างก่อสร้างจ้างก่อสร้างอาคารเรียนสา...        479479000

# %%
fig = px.bar(sum_pj, x='project_name', y='sum_price_agree')
fig.update_layout(
    title="Plot Title",
    font=dict(size=5))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="00bbfddd-8f4a-444f-82a0-5113678b9617" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00bbfddd-8f4a-444f-82a0-5113678b9617")) {                    Plotly.newPlot(                        "00bbfddd-8f4a-444f-82a0-5113678b9617",                        [{"alignmentgroup":"True","hovertemplate":"project_name=%{x}<br>sum_price_agree=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["